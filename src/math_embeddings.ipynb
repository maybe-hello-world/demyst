# %% [markdown]
# ## Embedding math

# %% [markdown]
# ## perf dataset: iperf vs qperf, cubic vs reno

# %%
data = {
    "etbert": "../data/etbert/perf_emb.pkl",
    "yatc": "../data/yatc/perf_emb.pkl",
    "netmamba": "../data/netmamba/netmamba_perf_emb.pkl",
    "netfound": "../data/netfound/perf_emb.pkl",
}

mapping = lambda x: x.split("/")[-1].split('.')[0][:-5]

# %%
import torch
import torch.nn.functional as F
import pickle
import os
import numpy as np

def measure_spread(tensor1, tensor2):
    similarity_matrix = F.cosine_similarity(tensor1.unsqueeze(1), tensor2.unsqueeze(0), dim=2)
    return similarity_matrix.mean()

def measure_dist(tensor1: torch.Tensor, tensor2: torch.Tensor) -> float:
    diff = torch.abs(tensor1.unsqueeze(1) - tensor2.unsqueeze(0))
    distances = diff.sum(dim=2)
    return distances.mean().item()

# %%
for model, path in data.items():
    with open(path, "rb") as f:
        embeddings, labels = pickle.load(f)
    labels = [mapping(x) for x in labels]
    print(labels)
# Out:
# ['qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic']
# ['iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno']
# ['iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno']
# ['qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-reno', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'qperf-cubic', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-reno', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic', 'iperf-cubic']

# %%
"""
experiments:
'qperf-cubic' - QUIC + Cubic
'qperf-reno' - QUIC + Reno
'iperf-cubic' - TCP + Cubic
'iperf-reno' - TCP + Reno
"""

order = ['qperf-cubic', 'iperf-reno', 'iperf-cubic', 'qperf-reno']

for model, path in data.items():
    with open(path, "rb") as f:
        embeddings, labels = pickle.load(f)
    labels = [mapping(x) for x in labels]
    assert isinstance(embeddings, torch.Tensor)
    assert embeddings.size(0) == len(labels)
    classes = {
        x: embeddings[torch.tensor([label == x for label in labels], dtype=torch.bool)]
        for x in set(labels)
    }

    mean_cos_sim = np.mean([measure_spread(classes[label], classes[label]) for label in classes])
    mean_l1_dist = np.mean([measure_dist(classes[label], classes[label]) for label in classes])

    # self-similarity for baseline - stability test
    print(f"Model {model}, stability: avg_cosine_similarity = {mean_cos_sim:.4f}, avg_L1_dist = {mean_l1_dist:.0f}")

    import itertools
    pairs = list(itertools.combinations(order, 2))
    for pair in pairs:
        print(f"Model {model}, distance between {pair[0]} and {pair[1]}: avg_cosine_similarity = {measure_spread(classes[pair[0]], classes[pair[1]]):.4f}, avg_L1_dist = {measure_dist(classes[pair[0]], classes[pair[1]]):.0f}")

    # math
    resulting_emb = classes[order[0]] + classes[order[1]] - classes[order[2]]
    for i in range(4):
        if i == 3:
            print("Target ", end='')
        print(f"Model {model}, distance from ({order[0]} + {order[1]} - {order[2]}) to {order[i]}: avg_cosine_similarity = {measure_spread(resulting_emb, classes[order[i]]):.4f}, avg_L1_dist = {measure_dist(resulting_emb, classes[order[i]]):.0f}")
    print()
# Out:
# Model etbert, stability: avg_cosine_similarity = 0.9789, avg_L1_dist = 122
# Model etbert, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.9197, avg_L1_dist = 253
# Model etbert, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.9168, avg_L1_dist = 258
# Model etbert, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9814, avg_L1_dist = 118
# Model etbert, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9738, avg_L1_dist = 146
# Model etbert, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.9192, avg_L1_dist = 253
# Model etbert, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.9163, avg_L1_dist = 259
# Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9602, avg_L1_dist = 183
# Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.8986, avg_L1_dist = 290
# Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.8925, avg_L1_dist = 299
# Target Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9589, avg_L1_dist = 186
#
# Model yatc, stability: avg_cosine_similarity = 0.9280, avg_L1_dist = 19
# Model yatc, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.2125, avg_L1_dist = 48
# Model yatc, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.1644, avg_L1_dist = 51
# Model yatc, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9009, avg_L1_dist = 21
# Model yatc, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9409, avg_L1_dist = 22
# Model yatc, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.2222, avg_L1_dist = 47
# Model yatc, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.1742, avg_L1_dist = 51
# Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.8215, avg_L1_dist = 32
# Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.1408, avg_L1_dist = 57
# Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.0867, avg_L1_dist = 61
# Target Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.8112, avg_L1_dist = 32
#
# Model netmamba, stability: avg_cosine_similarity = 0.9628, avg_L1_dist = 24
# Model netmamba, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.4769, avg_L1_dist = 213
# Model netmamba, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.4776, avg_L1_dist = 213
# Model netmamba, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9192, avg_L1_dist = 48
# Model netmamba, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9995, avg_L1_dist = 6
# Model netmamba, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.4754, avg_L1_dist = 212
# Model netmamba, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.4759, avg_L1_dist = 212
# Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9948, avg_L1_dist = 20
# Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.4768, avg_L1_dist = 213
# Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.4775, avg_L1_dist = 213
# Target Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9186, avg_L1_dist = 49
#
# Model netfound, stability: avg_cosine_similarity = 0.9650, avg_L1_dist = 148
# Model netfound, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.4618, avg_L1_dist = 630
# Model netfound, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.4647, avg_L1_dist = 630
# Model netfound, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9752, avg_L1_dist = 132
# Model netfound, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9487, avg_L1_dist = 193
# Model netfound, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.4606, avg_L1_dist = 631
# Model netfound, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.4630, avg_L1_dist = 631
# Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9264, avg_L1_dist = 237
# Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.4370, avg_L1_dist = 663
# Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.4332, avg_L1_dist = 666
# Target Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9257, avg_L1_dist = 238

# %%
"""
experiments:
'qperf-cubic' - QUIC + Cubic
'qperf-reno' - QUIC + Reno
'iperf-cubic' - TCP + Cubic
'iperf-reno' - TCP + Reno
"""

order = ['qperf-cubic', 'iperf-reno', 'iperf-cubic', 'qperf-reno']

def intra_class_spread(t):
    n = t.size(0)
    sims = F.cosine_similarity(t.unsqueeze(1), t.unsqueeze(0), dim=2)
    off_diag = sims[~torch.eye(n, dtype=torch.bool, device=t.device)]
    return off_diag.mean().item()

for model, path in data.items():
    with open(path, "rb") as f:
        embeddings, labels = pickle.load(f)
    labels = [mapping(x) for x in labels]
    assert isinstance(embeddings, torch.Tensor)
    assert embeddings.size(0) == len(labels)
    classes = {
        x: embeddings[torch.tensor([label == x for label in labels], dtype=torch.bool)]
        for x in set(labels)
    }

    mean_cos_sim = np.mean([intra_class_spread(classes[label]) for label in classes])
    mean_l1_dist = np.mean([measure_dist(classes[label], classes[label]) for label in classes])

    # self-similarity for baseline - stability test
    print(f"Model {model}, stability: avg_cosine_similarity = {mean_cos_sim:.4f}, avg_L1_dist = {mean_l1_dist:.0f}")

    import itertools
    pairs = list(itertools.combinations(order, 2))
    for pair in pairs:
        centroids = {k: v.mean(dim=0) for k, v in classes.items()}
        result_vec = centroids['qperf-cubic'] + centroids['iperf-reno'] - centroids['iperf-cubic']

        print(f"Model {model}, distance between {pair[0]} and {pair[1]}: avg_cosine_similarity = {measure_spread(classes[pair[0]], classes[pair[1]]):.4f}, avg_L1_dist = {measure_dist(classes[pair[0]], classes[pair[1]]):.0f}")

    # math
    resulting_emb = (classes[order[0]].mean(dim=0) + classes[order[1]].mean(dim=0) - classes[order[2]].mean(dim=0)).unsqueeze(0)
    for i in range(4):
        if i == 3:
            print("Target ", end='')
        print(f"Model {model}, distance from ({order[0]} + {order[1]} - {order[2]}) to {order[i]}: avg_cosine_similarity = {measure_spread(resulting_emb, classes[order[i]]):.4f}, avg_L1_dist = {measure_dist(resulting_emb, classes[order[i]]):.0f}")
    print()
# Out:
# Model etbert, stability: avg_cosine_similarity = 0.9765, avg_L1_dist = 122
# Model etbert, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.9197, avg_L1_dist = 253
# Model etbert, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.9168, avg_L1_dist = 258
# Model etbert, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9814, avg_L1_dist = 118
# Model etbert, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9738, avg_L1_dist = 146
# Model etbert, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.9192, avg_L1_dist = 253
# Model etbert, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.9163, avg_L1_dist = 259
# Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9897, avg_L1_dist = 89
# Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.9260, avg_L1_dist = 242
# Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.9196, avg_L1_dist = 254
# Target Model etbert, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9883, avg_L1_dist = 95
#
# Model yatc, stability: avg_cosine_similarity = 0.9200, avg_L1_dist = 19
# Model yatc, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.2125, avg_L1_dist = 48
# Model yatc, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.1644, avg_L1_dist = 51
# Model yatc, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9009, avg_L1_dist = 21
# Model yatc, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9409, avg_L1_dist = 22
# Model yatc, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.2222, avg_L1_dist = 47
# Model yatc, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.1742, avg_L1_dist = 51
# Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9425, avg_L1_dist = 17
# Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.1382, avg_L1_dist = 49
# Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.0744, avg_L1_dist = 53
# Target Model yatc, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9313, avg_L1_dist = 17
#
# Model netmamba, stability: avg_cosine_similarity = 0.9587, avg_L1_dist = 24
# Model netmamba, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.4769, avg_L1_dist = 213
# Model netmamba, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.4776, avg_L1_dist = 213
# Model netmamba, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9192, avg_L1_dist = 48
# Model netmamba, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9995, avg_L1_dist = 6
# Model netmamba, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.4754, avg_L1_dist = 212
# Model netmamba, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.4759, avg_L1_dist = 212
# Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9977, avg_L1_dist = 14
# Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.4782, avg_L1_dist = 213
# Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.4788, avg_L1_dist = 213
# Target Model netmamba, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9213, avg_L1_dist = 45
#
# Model netfound, stability: avg_cosine_similarity = 0.9611, avg_L1_dist = 148
# Model netfound, distance between qperf-cubic and iperf-reno: avg_cosine_similarity = 0.4618, avg_L1_dist = 630
# Model netfound, distance between qperf-cubic and iperf-cubic: avg_cosine_similarity = 0.4647, avg_L1_dist = 630
# Model netfound, distance between qperf-cubic and qperf-reno: avg_cosine_similarity = 0.9752, avg_L1_dist = 132
# Model netfound, distance between iperf-reno and iperf-cubic: avg_cosine_similarity = 0.9487, avg_L1_dist = 193
# Model netfound, distance between iperf-reno and qperf-reno: avg_cosine_similarity = 0.4606, avg_L1_dist = 631
# Model netfound, distance between iperf-cubic and qperf-reno: avg_cosine_similarity = 0.4630, avg_L1_dist = 631
# Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-cubic: avg_cosine_similarity = 0.9844, avg_L1_dist = 105
# Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-reno: avg_cosine_similarity = 0.4638, avg_L1_dist = 627
# Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to iperf-cubic: avg_cosine_similarity = 0.4595, avg_L1_dist = 630
# Target Model netfound, distance from (qperf-cubic + iperf-reno - iperf-cubic) to qperf-reno: avg_cosine_similarity = 0.9837, avg_L1_dist = 107

# %%
import torch, pickle, itertools
import torch.nn.functional as F
from pathlib import Path

data = {
    "etbert": "../data/etbert/perf_emb.pkl",
    "yatc":   "../data/yatc/perf_emb.pkl",
    "netmamba": "../data/netmamba/netmamba_perf_emb.pkl",
    "netfound": "../data/netfound/perf_emb.pkl",
}

order = ["qperf-cubic", "iperf-reno", "iperf-cubic", "qperf-reno"]
    

def pairwise_cos(a, b):
    return (F.normalize(a, dim=1) @ F.normalize(b, dim=1).T).mean().item()

def l1_mean(a, b):
    return torch.cdist(a, b, p=1).mean().item()

for model, path in data.items():
    emb, raw_labels = pickle.load(open(path, "rb"))
    labels = [mapping(x) for x in raw_labels]

    cls = {lab: emb[torch.tensor([l == lab for l in labels])] for lab in set(labels)}

    # intra-class spread without self-pairs
    intra = {k: pairwise_cos(v, v) for k, v in cls.items()}
    print(f"{model}: intra-class cosine (no diagonal) {intra}")

    # pairwise class similarity
    for a, b in itertools.combinations(order, 2):
        print(f"{model}: cos({a},{b}) = {pairwise_cos(cls[a], cls[b]):.4f}, "
              f"L1 = {l1_mean(cls[a], cls[b]):.2f}")

    # centroids & analogy
    centroids = {k: v.mean(0) for k, v in cls.items()}
    analog_vec = centroids["qperf-cubic"] + centroids["iperf-reno"] - centroids["iperf-cubic"]

    for tgt in order:
        cos = F.cosine_similarity(analog_vec, centroids[tgt], dim=0).item()
        l1  = torch.dist(analog_vec, centroids[tgt], p=1).item()
        tag = "(target)" if tgt == "qperf-reno" else ""
        print(f"{model}: ‖qC + iR − iC – {tgt}‖  cos={cos:.4f}  L1={l1:.2f} {tag}")

    # delta-vectors check
    print(f"TCP/QUIC: {model}: analogy delta cosine = {F.cosine_similarity(centroids['qperf-cubic'] - centroids['iperf-cubic'], centroids['qperf-reno']  - centroids['iperf-reno'], dim=0).item():.4f}")
    print(f"Cubic/Reno: {model}: analogy delta cosine = {F.cosine_similarity(centroids['qperf-reno'] - centroids['qperf-cubic'], centroids['iperf-reno'] - centroids['iperf-cubic'], dim=0).item():.4f}\n")
# Out:
# etbert: intra-class cosine (no diagonal) {'qperf-reno': 0.9816374778747559, 'qperf-cubic': 0.9828145503997803, 'iperf-reno': 0.976349949836731, 'iperf-cubic': 0.9746482968330383}
# etbert: cos(qperf-cubic,iperf-reno) = 0.9197, L1 = 252.51
# etbert: cos(qperf-cubic,iperf-cubic) = 0.9168, L1 = 258.08
# etbert: cos(qperf-cubic,qperf-reno) = 0.9814, L1 = 117.65
# etbert: cos(iperf-reno,iperf-cubic) = 0.9738, L1 = 145.58
# etbert: cos(iperf-reno,qperf-reno) = 0.9192, L1 = 253.27
# etbert: cos(iperf-cubic,qperf-reno) = 0.9163, L1 = 258.84
# etbert: ‖qC + iR − iC – qperf-cubic‖  cos=0.9983  L1=37.24
# etbert: ‖qC + iR − iC – iperf-reno‖  cos=0.9371  L1=223.01
# etbert: ‖qC + iR − iC – iperf-cubic‖  cos=0.9315  L1=232.55
# etbert: ‖qC + iR − iC – qperf-reno‖  cos=0.9975  L1=45.09 (target)
# TCP/QUIC: etbert: analogy delta cosine = 0.9799
# Cubic/Reno: etbert: analogy delta cosine = 0.0026
#
# yatc: intra-class cosine (no diagonal) {'qperf-reno': 0.9072108268737793, 'qperf-cubic': 0.9107094407081604, 'iperf-reno': 0.9367818236351013, 'iperf-cubic': 0.9572399854660034}
# yatc: cos(qperf-cubic,iperf-reno) = 0.2125, L1 = 47.51
# yatc: cos(qperf-cubic,iperf-cubic) = 0.1644, L1 = 50.78
# yatc: cos(qperf-cubic,qperf-reno) = 0.9009, L1 = 20.70
# yatc: cos(iperf-reno,iperf-cubic) = 0.9409, L1 = 21.95
# yatc: cos(iperf-reno,qperf-reno) = 0.2222, L1 = 47.44
# yatc: cos(iperf-cubic,qperf-reno) = 0.1742, L1 = 50.70
# yatc: ‖qC + iR − iC – qperf-cubic‖  cos=0.9878  L1=7.68
# yatc: ‖qC + iR − iC – iperf-reno‖  cos=0.1374  L1=46.04
# yatc: ‖qC + iR − iC – iperf-cubic‖  cos=0.0733  L1=51.27
# yatc: ‖qC + iR − iC – qperf-reno‖  cos=0.9787  L1=10.04 (target)
# TCP/QUIC: yatc: analogy delta cosine = 0.9920
# Cubic/Reno: yatc: analogy delta cosine = 0.0077
#
# netmamba: intra-class cosine (no diagonal) {'qperf-reno': 0.8568357825279236, 'qperf-cubic': 0.9953843951225281, 'iperf-reno': 0.9994804859161377, 'iperf-cubic': 0.9996148943901062}
# netmamba: cos(qperf-cubic,iperf-reno) = 0.4769, L1 = 213.21
# netmamba: cos(qperf-cubic,iperf-cubic) = 0.4776, L1 = 213.08
# netmamba: cos(qperf-cubic,qperf-reno) = 0.9192, L1 = 47.76
# netmamba: cos(iperf-reno,iperf-cubic) = 0.9995, L1 = 5.85
# netmamba: cos(iperf-reno,qperf-reno) = 0.4754, L1 = 212.41
# netmamba: cos(iperf-cubic,qperf-reno) = 0.4759, L1 = 212.29
# netmamba: ‖qC + iR − iC – qperf-cubic‖  cos=1.0000  L1=1.17
# netmamba: ‖qC + iR − iC – iperf-reno‖  cos=0.4784  L1=212.79
# netmamba: ‖qC + iR − iC – iperf-cubic‖  cos=0.4789  L1=212.68
# netmamba: ‖qC + iR − iC – qperf-reno‖  cos=0.9954  L1=24.37 (target)
# TCP/QUIC: netmamba: analogy delta cosine = 0.9953
# Cubic/Reno: netmamba: analogy delta cosine = 0.0978
#
# netfound: intra-class cosine (no diagonal) {'qperf-reno': 0.9791616201400757, 'qperf-cubic': 0.9764891266822815, 'iperf-reno': 0.9458903670310974, 'iperf-cubic': 0.9583343267440796}
# netfound: cos(qperf-cubic,iperf-reno) = 0.4618, L1 = 630.41
# netfound: cos(qperf-cubic,iperf-cubic) = 0.4647, L1 = 629.86
# netfound: cos(qperf-cubic,qperf-reno) = 0.9752, L1 = 132.34
# netfound: cos(iperf-reno,iperf-cubic) = 0.9487, L1 = 193.16
# netfound: cos(iperf-reno,qperf-reno) = 0.4606, L1 = 631.23
# netfound: cos(iperf-cubic,qperf-reno) = 0.4630, L1 = 631.05
# netfound: ‖qC + iR − iC – qperf-cubic‖  cos=0.9962  L1=51.21
# netfound: ‖qC + iR − iC – iperf-reno‖  cos=0.4767  L1=607.96
# netfound: ‖qC + iR − iC – iperf-cubic‖  cos=0.4692  L1=615.89
# netfound: ‖qC + iR − iC – qperf-reno‖  cos=0.9941  L1=63.08 (target)
# TCP/QUIC: netfound: analogy delta cosine = 0.9945
# Cubic/Reno: netfound: analogy delta cosine = 0.0857

# %% [markdown]
# ## synth dataset: aqm, cc, cross

# %%
import torch
import torch.nn.functional as F
import pickle
import os
import numpy as np

def measure_spread(A, B, exclude_self=False):
    M = F.cosine_similarity(A.unsqueeze(1), B.unsqueeze(0), dim=2)
    if exclude_self and A.data_ptr()==B.data_ptr():
        M = M[~torch.eye(len(A), dtype=torch.bool, device=A.device)]
    return M.mean()

def measure_dist(tensor1: torch.Tensor, tensor2: torch.Tensor) -> float:
    diff = torch.abs(tensor1.unsqueeze(1) - tensor2.unsqueeze(0))
    distances = diff.sum(dim=2)
    return distances.mean().item()

data = {
    "etbert": "../data/etbert/synth_emb.pkl",
    "yatc": "../data/yatc/synth_emb.pkl",
    "netmamba": "../data/netmamba/netmamba_synth_emb.pkl",
    "netfound": "../data/netfound/synth_emb.pkl",
}

mapping = lambda x: '_'.join(x.split("/")[-1].split('.')[0].split("_")[:-1])

"""
experiments:
'fifo_6m_bbr_prof50_36' - baseline
'fifo_6m_cubic_prof50_36' - different cc algorithm
'codel_6m_bbr_prof50_36' - different AQM
'fifo_6m_bbr_prof72_29' - different cross traffic
'codel_6m_cubic_prof72_29' - different cc, aqm, and cross traffic

idea: cc + aqm + cross - 2*baseline == all
should work because each of 3 single change vectors have 1 change and 2 variables the same
fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 = 2x fifo, 2x bbr, 2x prof50, 1x cubic, 1x codel, 1x prof72
so we retract 2x fifo_6m_bbr_prof50_36 and should get 1x cubic, 1x codel, 1x prof72 which is codel_6m_cubic_prof72_29
"""

order = ['fifo_6m_cubic_prof50_36', 'codel_6m_bbr_prof50_36', 'fifo_6m_bbr_prof72_29', 'fifo_6m_bbr_prof50_36', 'codel_6m_cubic_prof72_29']

for model, path in data.items():
    with open(path, "rb") as f:
        embeddings, labels = pickle.load(f)
    labels = [mapping(x) for x in labels]
    assert isinstance(embeddings, torch.Tensor)
    assert embeddings.size(0) == len(labels)
    classes = {
        x: embeddings[torch.tensor([label == x for label in labels], dtype=torch.bool)]
        for x in set(labels)
    }

    mean_cos_sim = np.mean([measure_spread(classes[label], classes[label], exclude_self=True) for label in classes])
    mean_l1_dist = np.mean([measure_dist(classes[label], classes[label]) for label in classes])

    # self-similarity for baseline - stability test
    print(f"Model {model}, stability: avg_cosine_similarity = {mean_cos_sim:.4f}, avg_L1_dist = {mean_l1_dist:.1f}")
    print(f"Model {model}, baseline stability: avg_cosine_similarity = {measure_spread(classes['fifo_6m_bbr_prof50_36'], classes['fifo_6m_bbr_prof50_36'], exclude_self=True):.4f}, avg_L1_dist = {measure_dist(classes['fifo_6m_bbr_prof50_36'], classes['fifo_6m_bbr_prof50_36']):.1f}")

    import itertools
    pairs = list(itertools.combinations(order, 2))
    for pair in pairs:
        print(f"Model {model}, distance between {pair[0]} and {pair[1]}: avg_cosine_similarity = {measure_spread(classes[pair[0]], classes[pair[1]]):.4f}, avg_L1_dist = {measure_dist(classes[pair[0]], classes[pair[1]]):.1f}")

    # math
    # getting centroids
    resulting_emb = (classes[order[0]].mean(dim=0) + classes[order[1]].mean(dim=0) + classes[order[2]].mean(dim=0) - 2*classes[order[3]].mean(dim=0)).unsqueeze(0)
    for i in range(5):
        if i == 4:
            print("Target ", end='')
        print(f"Model {model}, distance from ({order[0]} + {order[1]} + {order[2]} - 2x {order[3]}) to {order[i]}: avg_cosine_similarity = {measure_spread(resulting_emb, classes[order[i]]):.4f}, avg_L1_dist = {measure_dist(resulting_emb, classes[order[i]]):.1f}")
    print()
# Out:
# Model etbert, stability: avg_cosine_similarity = 0.9689, avg_L1_dist = 155.6
# Model etbert, baseline stability: avg_cosine_similarity = 0.9695, avg_L1_dist = 154.8
# Model etbert, distance between fifo_6m_cubic_prof50_36 and codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9679, avg_L1_dist = 159.4
# Model etbert, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9715, avg_L1_dist = 150.9
# Model etbert, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9703, avg_L1_dist = 153.8
# Model etbert, distance between fifo_6m_cubic_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9686, avg_L1_dist = 157.6
# Model etbert, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9686, avg_L1_dist = 158.1
# Model etbert, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9673, avg_L1_dist = 161.2
# Model etbert, distance between codel_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9659, avg_L1_dist = 164.2
# Model etbert, distance between fifo_6m_bbr_prof72_29 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9708, avg_L1_dist = 153.0
# Model etbert, distance between fifo_6m_bbr_prof72_29 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9692, avg_L1_dist = 156.5
# Model etbert, distance between fifo_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9679, avg_L1_dist = 159.6
# Model etbert, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_cubic_prof50_36: avg_cosine_similarity = 0.9846, avg_L1_dist = 109.4
# Model etbert, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9821, avg_L1_dist = 118.8
# Model etbert, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9853, avg_L1_dist = 108.5
# Model etbert, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9833, avg_L1_dist = 114.6
# Target Model etbert, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9823, avg_L1_dist = 117.7
#
# Model yatc, stability: avg_cosine_similarity = 0.8935, avg_L1_dist = 27.8
# Model yatc, baseline stability: avg_cosine_similarity = 0.8929, avg_L1_dist = 27.7
# Model yatc, distance between fifo_6m_cubic_prof50_36 and codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.8924, avg_L1_dist = 28.2
# Model yatc, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.8892, avg_L1_dist = 28.6
# Model yatc, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.8899, avg_L1_dist = 28.3
# Model yatc, distance between fifo_6m_cubic_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.8929, avg_L1_dist = 28.0
# Model yatc, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.8940, avg_L1_dist = 28.3
# Model yatc, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.8942, avg_L1_dist = 28.0
# Model yatc, distance between codel_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.8971, avg_L1_dist = 27.7
# Model yatc, distance between fifo_6m_bbr_prof72_29 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.8922, avg_L1_dist = 28.3
# Model yatc, distance between fifo_6m_bbr_prof72_29 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.8949, avg_L1_dist = 28.0
# Model yatc, distance between fifo_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.8960, avg_L1_dist = 27.7
# Model yatc, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_cubic_prof50_36: avg_cosine_similarity = 0.9385, avg_L1_dist = 20.9
# Model yatc, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9445, avg_L1_dist = 20.3
# Model yatc, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9385, avg_L1_dist = 21.1
# Model yatc, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9360, avg_L1_dist = 21.1
# Target Model yatc, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9408, avg_L1_dist = 20.4
#
# Model netmamba, stability: avg_cosine_similarity = 0.9568, avg_L1_dist = 29.4
# Model netmamba, baseline stability: avg_cosine_similarity = 0.9939, avg_L1_dist = 20.9
# Model netmamba, distance between fifo_6m_cubic_prof50_36 and codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9099, avg_L1_dist = 41.2
# Model netmamba, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9943, avg_L1_dist = 20.4
# Model netmamba, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9942, avg_L1_dist = 20.7
# Model netmamba, distance between fifo_6m_cubic_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9814, avg_L1_dist = 23.5
# Model netmamba, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9099, avg_L1_dist = 41.1
# Model netmamba, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9097, avg_L1_dist = 41.4
# Model netmamba, distance between codel_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.8983, avg_L1_dist = 43.9
# Model netmamba, distance between fifo_6m_bbr_prof72_29 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9942, avg_L1_dist = 20.7
# Model netmamba, distance between fifo_6m_bbr_prof72_29 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9814, avg_L1_dist = 23.6
# Model netmamba, distance between fifo_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9813, avg_L1_dist = 23.8
# Model netmamba, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_cubic_prof50_36: avg_cosine_similarity = 0.9958, avg_L1_dist = 25.1
# Model netmamba, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9134, avg_L1_dist = 44.2
# Model netmamba, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9960, avg_L1_dist = 24.7
# Model netmamba, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9955, avg_L1_dist = 25.3
# Target Model netmamba, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9830, avg_L1_dist = 28.1
#
# Model netfound, stability: avg_cosine_similarity = 0.9587, avg_L1_dist = 131.8
# Model netfound, baseline stability: avg_cosine_similarity = 0.9697, avg_L1_dist = 120.6
# Model netfound, distance between fifo_6m_cubic_prof50_36 and codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9538, avg_L1_dist = 139.6
# Model netfound, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9596, avg_L1_dist = 132.8
# Model netfound, distance between fifo_6m_cubic_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9669, avg_L1_dist = 126.7
# Model netfound, distance between fifo_6m_cubic_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9252, avg_L1_dist = 175.7
# Model netfound, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9498, avg_L1_dist = 147.7
# Model netfound, distance between codel_6m_bbr_prof50_36 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9515, avg_L1_dist = 149.2
# Model netfound, distance between codel_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9287, avg_L1_dist = 171.9
# Model netfound, distance between fifo_6m_bbr_prof72_29 and fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9591, avg_L1_dist = 137.5
# Model netfound, distance between fifo_6m_bbr_prof72_29 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9277, avg_L1_dist = 176.4
# Model netfound, distance between fifo_6m_bbr_prof50_36 and codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9173, avg_L1_dist = 194.5
# Model netfound, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_cubic_prof50_36: avg_cosine_similarity = 0.9574, avg_L1_dist = 137.1
# Model netfound, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_bbr_prof50_36: avg_cosine_similarity = 0.9617, avg_L1_dist = 129.7
# Model netfound, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof72_29: avg_cosine_similarity = 0.9556, avg_L1_dist = 145.2
# Model netfound, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to fifo_6m_bbr_prof50_36: avg_cosine_similarity = 0.9448, avg_L1_dist = 169.0
# Target Model netfound, distance from (fifo_6m_cubic_prof50_36 + codel_6m_bbr_prof50_36 + fifo_6m_bbr_prof72_29 - 2x fifo_6m_bbr_prof50_36) to codel_6m_cubic_prof72_29: avg_cosine_similarity = 0.9596, avg_L1_dist = 125.9
